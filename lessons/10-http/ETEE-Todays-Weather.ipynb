# %% [markdown]
# # End-To-End Example: Today's Weather
#
# This example will input a location and then output today's current weather conditions at that location.
#
# To complete this example we will use the following API's
#
# - https://www.openstreetmap.org/ Geocode api to get GPS coordinates for a location eg. Syracuse, NY
# - https://openweathermap.org/ forecast api to get the currnt weather conditions for those GPS coordinates

# %%
# Todo list
# input a location eg. Syracuse, ny
# use the google geocode api to get a lat/lng
# use the darksky api and lat/lng to get current weather conditions
# output current weather conditions (temperature and summary (rain, snow, etc...))

# %%
import requests

# %%
def geocode(location):
    query_string = {'q' : location, 'format': 'json'}
    url='https://nominatim.openstreetmap.org/search' 
    response = requests.get(url, params = query_string)
    response.raise_for_status()
    geodata = response.json()
    #print(response.url)
    return geodata
        
# Testing with syracuse, NY 
geocode('Syracuse, NY')
# Out:
# [{'place_id': 332268789,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 174916,
#   'boundingbox': ['42.984165', '43.086121', '-76.204629', '-76.074273'],
#   'lat': '43.0481221',
#   'lon': '-76.1474244',
#   'display_name': 'City of Syracuse, Onondaga County, New York, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6767762857760726,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'},
#  {'place_id': 67315254,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 6241108067,
#   'boundingbox': ['43.0718312', '43.0818312', '-76.1744003', '-76.1644003'],
#   'lat': '43.0768312',
#   'lon': '-76.1694003',
#   'display_name': 'Syracuse, 131, NBT Bank Parkway, City of Syracuse, Onondaga County, New York, 13208, United States',
#   'class': 'railway',
#   'type': 'station',
#   'importance': 0.4272524353626238,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//transport_train_station2.p.20.png'},
#  {'place_id': 36341573,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 2997656284,
#   'boundingbox': ['43.0770382', '43.0771382', '-76.1700021', '-76.1699021'],
#   'lat': '43.0770882',
#   'lon': '-76.1699521',
#   'display_name': 'Syracuse, Walsh Circle, City of Syracuse, Onondaga County, New York, 13290, United States',
#   'class': 'railway',
#   'type': 'stop',
#   'importance': 0.11100000000000002}]

# %%
def getweather(lat,lon):
    key = '67f9d45c32dd086df27f2b7a90370a8e' # sign up for your own key at https://openweathermap.org/ 
    query_string = { 'lat' : lat, 'lon': lon, 'appid' : key, 'units' : 'imperial'}
    url='https://api.openweathermap.org/data/2.5/onecall' 
    response = requests.get(url, params=query_string)
    response.raise_for_status()
    #print (response.url)
    weather = response.json()
    return weather

# Testing with syracuse, NY coordinates
getweather( 43.0481221, -76.1474244 )
# Out:
# {'lat': 43.0481,
#  'lon': -76.1474,
#  'timezone': 'America/New_York',
#  'timezone_offset': -14400,
#  'current': {'dt': 1649099918,
#   'sunrise': 1649068870,
#   'sunset': 1649115214,
#   'temp': 43.38,
#   'feels_like': 38.16,
#   'pressure': 1016,
#   'humidity': 70,
#   'dew_point': 34.27,
#   'uvi': 2.8,
#   'clouds': 75,
#   'visibility': 10000,
#   'wind_speed': 9.22,
#   'wind_deg': 260,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}]},
#  'minutely': [{'dt': 1649099940, 'precipitation': 0},
#   {'dt': 1649100000, 'precipitation': 0},
#   {'dt': 1649100060, 'precipitation': 0},
#   {'dt': 1649100120, 'precipitation': 0},
#   {'dt': 1649100180, 'precipitation': 0},
#   {'dt': 1649100240, 'precipitation': 0},
#   {'dt': 1649100300, 'precipitation': 0},
#   {'dt': 1649100360, 'precipitation': 0},
#   {'dt': 1649100420, 'precipitation': 0},
#   {'dt': 1649100480, 'precipitation': 0},
#   {'dt': 1649100540, 'precipitation': 0},
#   {'dt': 1649100600, 'precipitation': 0},
#   {'dt': 1649100660, 'precipitation': 0},
#   {'dt': 1649100720, 'precipitation': 0},
#   {'dt': 1649100780, 'precipitation': 0},
#   {'dt': 1649100840, 'precipitation': 0},
#   {'dt': 1649100900, 'precipitation': 0},
#   {'dt': 1649100960, 'precipitation': 0},
#   {'dt': 1649101020, 'precipitation': 0},
#   {'dt': 1649101080, 'precipitation': 0},
#   {'dt': 1649101140, 'precipitation': 0},
#   {'dt': 1649101200, 'precipitation': 0},
#   {'dt': 1649101260, 'precipitation': 0},
#   {'dt': 1649101320, 'precipitation': 0},
#   {'dt': 1649101380, 'precipitation': 0},
#   {'dt': 1649101440, 'precipitation': 0},
#   {'dt': 1649101500, 'precipitation': 0},
#   {'dt': 1649101560, 'precipitation': 0},
#   {'dt': 1649101620, 'precipitation': 0},
#   {'dt': 1649101680, 'precipitation': 0},
#   {'dt': 1649101740, 'precipitation': 0},
#   {'dt': 1649101800, 'precipitation': 0},
#   {'dt': 1649101860, 'precipitation': 0},
#   {'dt': 1649101920, 'precipitation': 0},
#   {'dt': 1649101980, 'precipitation': 0},
#   {'dt': 1649102040, 'precipitation': 0},
#   {'dt': 1649102100, 'precipitation': 0},
#   {'dt': 1649102160, 'precipitation': 0},
#   {'dt': 1649102220, 'precipitation': 0},
#   {'dt': 1649102280, 'precipitation': 0},
#   {'dt': 1649102340, 'precipitation': 0},
#   {'dt': 1649102400, 'precipitation': 0},
#   {'dt': 1649102460, 'precipitation': 0},
#   {'dt': 1649102520, 'precipitation': 0},
#   {'dt': 1649102580, 'precipitation': 0},
#   {'dt': 1649102640, 'precipitation': 0},
#   {'dt': 1649102700, 'precipitation': 0},
#   {'dt': 1649102760, 'precipitation': 0},
#   {'dt': 1649102820, 'precipitation': 0},
#   {'dt': 1649102880, 'precipitation': 0},
#   {'dt': 1649102940, 'precipitation': 0},
#   {'dt': 1649103000, 'precipitation': 0},
#   {'dt': 1649103060, 'precipitation': 0},
#   {'dt': 1649103120, 'precipitation': 0},
#   {'dt': 1649103180, 'precipitation': 0},
#   {'dt': 1649103240, 'precipitation': 0},
#   {'dt': 1649103300, 'precipitation': 0},
#   {'dt': 1649103360, 'precipitation': 0},
#   {'dt': 1649103420, 'precipitation': 0},
#   {'dt': 1649103480, 'precipitation': 0},
#   {'dt': 1649103540, 'precipitation': 0}],
#  'hourly': [{'dt': 1649098800,
#    'temp': 43.38,
#    'feels_like': 39.72,
#    'pressure': 1016,
#    'humidity': 70,
#    'dew_point': 34.27,
#    'uvi': 2.8,
#    'clouds': 75,
#    'visibility': 10000,
#    'wind_speed': 6.11,
#    'wind_deg': 283,
#    'wind_gust': 9.01,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649102400,
#    'temp': 43.3,
#    'feels_like': 40.33,
#    'pressure': 1016,
#    'humidity': 69,
#    'dew_point': 33.84,
#    'uvi': 1.85,
#    'clouds': 80,
#    'visibility': 10000,
#    'wind_speed': 5.03,
#    'wind_deg': 283,
#    'wind_gust': 7.63,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649106000,
#    'temp': 43.32,
#    'feels_like': 40.71,
#    'pressure': 1016,
#    'humidity': 69,
#    'dew_point': 33.85,
#    'uvi': 0.96,
#    'clouds': 85,
#    'visibility': 10000,
#    'wind_speed': 4.54,
#    'wind_deg': 286,
#    'wind_gust': 6.87,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649109600,
#    'temp': 43.45,
#    'feels_like': 43.45,
#    'pressure': 1016,
#    'humidity': 68,
#    'dew_point': 33.6,
#    'uvi': 0.36,
#    'clouds': 90,
#    'visibility': 10000,
#    'wind_speed': 2.93,
#    'wind_deg': 305,
#    'wind_gust': 4.74,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649113200,
#    'temp': 41.31,
#    'feels_like': 41.31,
#    'pressure': 1016,
#    'humidity': 74,
#    'dew_point': 33.66,
#    'uvi': 0,
#    'clouds': 95,
#    'visibility': 10000,
#    'wind_speed': 1.52,
#    'wind_deg': 338,
#    'wind_gust': 1.92,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649116800,
#    'temp': 38.43,
#    'feels_like': 38.43,
#    'pressure': 1016,
#    'humidity': 78,
#    'dew_point': 31.28,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 1.01,
#    'wind_deg': 82,
#    'wind_gust': 1.74,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649120400,
#    'temp': 37.47,
#    'feels_like': 37.47,
#    'pressure': 1017,
#    'humidity': 80,
#    'dew_point': 31.12,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.28,
#    'wind_deg': 167,
#    'wind_gust': 2.48,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649124000,
#    'temp': 36.66,
#    'feels_like': 33.78,
#    'pressure': 1017,
#    'humidity': 83,
#    'dew_point': 31.1,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 3.69,
#    'wind_deg': 169,
#    'wind_gust': 3.4,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649127600,
#    'temp': 36.59,
#    'feels_like': 33.37,
#    'pressure': 1017,
#    'humidity': 84,
#    'dew_point': 31.26,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 4,
#    'wind_deg': 170,
#    'wind_gust': 3.76,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649131200,
#    'temp': 35.94,
#    'feels_like': 31.96,
#    'pressure': 1017,
#    'humidity': 85,
#    'dew_point': 30.99,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 4.7,
#    'wind_deg': 169,
#    'wind_gust': 4.92,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649134800,
#    'temp': 35.44,
#    'feels_like': 31.19,
#    'pressure': 1017,
#    'humidity': 85,
#    'dew_point': 30.63,
#    'uvi': 0,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 4.92,
#    'wind_deg': 166,
#    'wind_gust': 5.35,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649138400,
#    'temp': 34.92,
#    'feels_like': 30.54,
#    'pressure': 1017,
#    'humidity': 85,
#    'dew_point': 30.09,
#    'uvi': 0,
#    'clouds': 95,
#    'visibility': 10000,
#    'wind_speed': 4.94,
#    'wind_deg': 163,
#    'wind_gust': 5.82,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649142000,
#    'temp': 34.25,
#    'feels_like': 30.22,
#    'pressure': 1017,
#    'humidity': 86,
#    'dew_point': 29.7,
#    'uvi': 0,
#    'clouds': 45,
#    'visibility': 10000,
#    'wind_speed': 4.45,
#    'wind_deg': 160,
#    'wind_gust': 4.99,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1649145600,
#    'temp': 33.84,
#    'feels_like': 29.7,
#    'pressure': 1017,
#    'humidity': 87,
#    'dew_point': 29.57,
#    'uvi': 0,
#    'clouds': 33,
#    'visibility': 10000,
#    'wind_speed': 4.5,
#    'wind_deg': 153,
#    'wind_gust': 5.48,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1649149200,
#    'temp': 33.66,
#    'feels_like': 29.14,
#    'pressure': 1016,
#    'humidity': 87,
#    'dew_point': 29.37,
#    'uvi': 0,
#    'clouds': 33,
#    'visibility': 10000,
#    'wind_speed': 4.88,
#    'wind_deg': 145,
#    'wind_gust': 6.64,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1649152800,
#    'temp': 33.42,
#    'feels_like': 28.85,
#    'pressure': 1016,
#    'humidity': 88,
#    'dew_point': 29.32,
#    'uvi': 0,
#    'clouds': 32,
#    'visibility': 10000,
#    'wind_speed': 4.88,
#    'wind_deg': 136,
#    'wind_gust': 7.11,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1649156400,
#    'temp': 33.91,
#    'feels_like': 29.08,
#    'pressure': 1016,
#    'humidity': 87,
#    'dew_point': 29.48,
#    'uvi': 0,
#    'clouds': 38,
#    'visibility': 10000,
#    'wind_speed': 5.28,
#    'wind_deg': 127,
#    'wind_gust': 8.37,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1649160000,
#    'temp': 37.17,
#    'feels_like': 33.87,
#    'pressure': 1017,
#    'humidity': 82,
#    'dew_point': 31.5,
#    'uvi': 0.35,
#    'clouds': 42,
#    'visibility': 10000,
#    'wind_speed': 4.18,
#    'wind_deg': 124,
#    'wind_gust': 9.35,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1649163600,
#    'temp': 41.79,
#    'feels_like': 39.18,
#    'pressure': 1017,
#    'humidity': 74,
#    'dew_point': 33.1,
#    'uvi': 0.99,
#    'clouds': 61,
#    'visibility': 10000,
#    'wind_speed': 4.23,
#    'wind_deg': 136,
#    'wind_gust': 8.1,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649167200,
#    'temp': 46.17,
#    'feels_like': 43.81,
#    'pressure': 1016,
#    'humidity': 67,
#    'dew_point': 34.97,
#    'uvi': 2.01,
#    'clouds': 40,
#    'visibility': 10000,
#    'wind_speed': 4.85,
#    'wind_deg': 144,
#    'wind_gust': 9.26,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1649170800,
#    'temp': 49.8,
#    'feels_like': 47.8,
#    'pressure': 1016,
#    'humidity': 62,
#    'dew_point': 36.7,
#    'uvi': 3.18,
#    'clouds': 40,
#    'visibility': 10000,
#    'wind_speed': 5.32,
#    'wind_deg': 151,
#    'wind_gust': 8.88,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1649174400,
#    'temp': 52.95,
#    'feels_like': 50.72,
#    'pressure': 1015,
#    'humidity': 59,
#    'dew_point': 37.99,
#    'uvi': 4.25,
#    'clouds': 34,
#    'visibility': 10000,
#    'wind_speed': 5.57,
#    'wind_deg': 159,
#    'wind_gust': 8.46,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1649178000,
#    'temp': 55.44,
#    'feels_like': 53.26,
#    'pressure': 1014,
#    'humidity': 55,
#    'dew_point': 38.62,
#    'uvi': 4.67,
#    'clouds': 30,
#    'visibility': 10000,
#    'wind_speed': 5.86,
#    'wind_deg': 158,
#    'wind_gust': 8.39,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1649181600,
#    'temp': 57.56,
#    'feels_like': 55.42,
#    'pressure': 1013,
#    'humidity': 51,
#    'dew_point': 38.77,
#    'uvi': 4.38,
#    'clouds': 29,
#    'visibility': 10000,
#    'wind_speed': 5.37,
#    'wind_deg': 165,
#    'wind_gust': 8.43,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1649185200,
#    'temp': 58.71,
#    'feels_like': 56.59,
#    'pressure': 1012,
#    'humidity': 49,
#    'dew_point': 38.75,
#    'uvi': 3.06,
#    'clouds': 58,
#    'visibility': 10000,
#    'wind_speed': 4.85,
#    'wind_deg': 161,
#    'wind_gust': 7.76,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649188800,
#    'temp': 57.7,
#    'feels_like': 55.58,
#    'pressure': 1012,
#    'humidity': 51,
#    'dew_point': 38.84,
#    'uvi': 2.03,
#    'clouds': 78,
#    'visibility': 10000,
#    'wind_speed': 4.85,
#    'wind_deg': 155,
#    'wind_gust': 7.96,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649192400,
#    'temp': 55.2,
#    'feels_like': 53.33,
#    'pressure': 1011,
#    'humidity': 62,
#    'dew_point': 41.49,
#    'uvi': 1.05,
#    'clouds': 86,
#    'visibility': 10000,
#    'wind_speed': 4.52,
#    'wind_deg': 93,
#    'wind_gust': 7.63,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649196000,
#    'temp': 53.82,
#    'feels_like': 51.94,
#    'pressure': 1012,
#    'humidity': 65,
#    'dew_point': 41.4,
#    'uvi': 0.29,
#    'clouds': 89,
#    'visibility': 10000,
#    'wind_speed': 5.48,
#    'wind_deg': 102,
#    'wind_gust': 10.76,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649199600,
#    'temp': 51.71,
#    'feels_like': 49.82,
#    'pressure': 1012,
#    'humidity': 69,
#    'dew_point': 40.98,
#    'uvi': 0.05,
#    'clouds': 91,
#    'visibility': 10000,
#    'wind_speed': 6.08,
#    'wind_deg': 104,
#    'wind_gust': 10.98,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649203200,
#    'temp': 49.73,
#    'feels_like': 47.05,
#    'pressure': 1012,
#    'humidity': 74,
#    'dew_point': 40.86,
#    'uvi': 0,
#    'clouds': 93,
#    'visibility': 10000,
#    'wind_speed': 6.6,
#    'wind_deg': 115,
#    'wind_gust': 14.54,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649206800,
#    'temp': 46.9,
#    'feels_like': 43.52,
#    'pressure': 1013,
#    'humidity': 81,
#    'dew_point': 40.51,
#    'uvi': 0,
#    'clouds': 90,
#    'visibility': 10000,
#    'wind_speed': 6.87,
#    'wind_deg': 128,
#    'wind_gust': 15.86,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649210400,
#    'temp': 46.2,
#    'feels_like': 42.49,
#    'pressure': 1013,
#    'humidity': 84,
#    'dew_point': 40.8,
#    'uvi': 0,
#    'clouds': 95,
#    'visibility': 10000,
#    'wind_speed': 7.23,
#    'wind_deg': 132,
#    'wind_gust': 20.22,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649214000,
#    'temp': 46.24,
#    'feels_like': 42.53,
#    'pressure': 1012,
#    'humidity': 84,
#    'dew_point': 41.05,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 7.25,
#    'wind_deg': 139,
#    'wind_gust': 20.67,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649217600,
#    'temp': 45.27,
#    'feels_like': 41.77,
#    'pressure': 1012,
#    'humidity': 87,
#    'dew_point': 40.82,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 6.44,
#    'wind_deg': 126,
#    'wind_gust': 17.18,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649221200,
#    'temp': 44.26,
#    'feels_like': 40.87,
#    'pressure': 1012,
#    'humidity': 88,
#    'dew_point': 40.21,
#    'uvi': 0,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 5.93,
#    'wind_deg': 118,
#    'wind_gust': 13.87,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649224800,
#    'temp': 43.99,
#    'feels_like': 40.19,
#    'pressure': 1012,
#    'humidity': 88,
#    'dew_point': 39.7,
#    'uvi': 0,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 6.55,
#    'wind_deg': 117,
#    'wind_gust': 18.32,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649228400,
#    'temp': 43.57,
#    'feels_like': 39.7,
#    'pressure': 1011,
#    'humidity': 88,
#    'dew_point': 39.45,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.53,
#    'wind_deg': 111,
#    'wind_gust': 17.69,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649232000,
#    'temp': 43.12,
#    'feels_like': 39.43,
#    'pressure': 1011,
#    'humidity': 90,
#    'dew_point': 39.33,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.06,
#    'wind_deg': 106,
#    'wind_gust': 16.26,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649235600,
#    'temp': 43.14,
#    'feels_like': 39.7,
#    'pressure': 1011,
#    'humidity': 90,
#    'dew_point': 39.4,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.68,
#    'wind_deg': 93,
#    'wind_gust': 11.41,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649239200,
#    'temp': 42.94,
#    'feels_like': 39.06,
#    'pressure': 1011,
#    'humidity': 90,
#    'dew_point': 39.31,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.33,
#    'wind_deg': 99,
#    'wind_gust': 11.56,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1649242800,
#    'temp': 43.83,
#    'feels_like': 39.72,
#    'pressure': 1010,
#    'humidity': 89,
#    'dew_point': 39.83,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 7.05,
#    'wind_deg': 102,
#    'wind_gust': 19.1,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649246400,
#    'temp': 46.13,
#    'feels_like': 42.39,
#    'pressure': 1010,
#    'humidity': 86,
#    'dew_point': 41.13,
#    'uvi': 0.29,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 7.29,
#    'wind_deg': 103,
#    'wind_gust': 20.71,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649250000,
#    'temp': 49.86,
#    'feels_like': 46.2,
#    'pressure': 1010,
#    'humidity': 79,
#    'dew_point': 42.93,
#    'uvi': 0.56,
#    'clouds': 59,
#    'visibility': 10000,
#    'wind_speed': 8.99,
#    'wind_deg': 104,
#    'wind_gust': 18.19,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649253600,
#    'temp': 53.29,
#    'feels_like': 51.85,
#    'pressure': 1010,
#    'humidity': 75,
#    'dew_point': 44.58,
#    'uvi': 1.14,
#    'clouds': 55,
#    'visibility': 10000,
#    'wind_speed': 10.71,
#    'wind_deg': 105,
#    'wind_gust': 16.8,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649257200,
#    'temp': 53.6,
#    'feels_like': 52.18,
#    'pressure': 1010,
#    'humidity': 75,
#    'dew_point': 45.14,
#    'uvi': 1.81,
#    'clouds': 68,
#    'visibility': 10000,
#    'wind_speed': 11.88,
#    'wind_deg': 113,
#    'wind_gust': 18.95,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649260800,
#    'temp': 53.01,
#    'feels_like': 51.58,
#    'pressure': 1009,
#    'humidity': 76,
#    'dew_point': 44.76,
#    'uvi': 3.85,
#    'clouds': 75,
#    'visibility': 10000,
#    'wind_speed': 12.75,
#    'wind_deg': 118,
#    'wind_gust': 22.46,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649264400,
#    'temp': 53.87,
#    'feels_like': 52.43,
#    'pressure': 1009,
#    'humidity': 74,
#    'dew_point': 44.98,
#    'uvi': 4.23,
#    'clouds': 80,
#    'visibility': 10000,
#    'wind_speed': 13.24,
#    'wind_deg': 117,
#    'wind_gust': 21.54,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1649268000,
#    'temp': 55.04,
#    'feels_like': 53.67,
#    'pressure': 1009,
#    'humidity': 73,
#    'dew_point': 45.72,
#    'uvi': 3.97,
#    'clouds': 83,
#    'visibility': 10000,
#    'wind_speed': 11.36,
#    'wind_deg': 113,
#    'wind_gust': 19.82,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0}],
#  'daily': [{'dt': 1649091600,
#    'sunrise': 1649068870,
#    'sunset': 1649115214,
#    'moonrise': 1649074920,
#    'moonset': 1649129100,
#    'moon_phase': 0.11,
#    'temp': {'day': 42.51,
#     'min': 33.01,
#     'max': 43.45,
#     'night': 36.59,
#     'eve': 41.31,
#     'morn': 33.01},
#    'feels_like': {'day': 37.99, 'night': 33.37, 'eve': 41.31, 'morn': 28.2},
#    'pressure': 1016,
#    'humidity': 72,
#    'dew_point': 34.14,
#    'wind_speed': 7.99,
#    'wind_deg': 309,
#    'wind_gust': 16.96,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 85,
#    'pop': 0.47,
#    'snow': 0.38,
#    'uvi': 4.39},
#   {'dt': 1649178000,
#    'sunrise': 1649155166,
#    'sunset': 1649201683,
#    'moonrise': 1649163120,
#    'moonset': 0,
#    'moon_phase': 0.14,
#    'temp': {'day': 55.44,
#     'min': 33.42,
#     'max': 58.71,
#     'night': 46.24,
#     'eve': 51.71,
#     'morn': 33.91},
#    'feels_like': {'day': 53.26, 'night': 42.53, 'eve': 49.82, 'morn': 29.08},
#    'pressure': 1014,
#    'humidity': 55,
#    'dew_point': 38.62,
#    'wind_speed': 7.25,
#    'wind_deg': 139,
#    'wind_gust': 20.67,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': 30,
#    'pop': 0,
#    'uvi': 4.67},
#   {'dt': 1649264400,
#    'sunrise': 1649241461,
#    'sunset': 1649288152,
#    'moonrise': 1649251560,
#    'moonset': 1649219280,
#    'moon_phase': 0.17,
#    'temp': {'day': 53.87,
#     'min': 42.94,
#     'max': 55.04,
#     'night': 49.95,
#     'eve': 51.15,
#     'morn': 43.83},
#    'feels_like': {'day': 52.43, 'night': 44.83, 'eve': 49.96, 'morn': 39.72},
#    'pressure': 1009,
#    'humidity': 74,
#    'dew_point': 44.98,
#    'wind_speed': 16.06,
#    'wind_deg': 131,
#    'wind_gust': 36.78,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 80,
#    'pop': 0.88,
#    'rain': 2.28,
#    'uvi': 4.23},
#   {'dt': 1649350800,
#    'sunrise': 1649327758,
#    'sunset': 1649374622,
#    'moonrise': 1649340480,
#    'moonset': 1649309340,
#    'moon_phase': 0.2,
#    'temp': {'day': 47.53,
#     'min': 45.3,
#     'max': 50.74,
#     'night': 45.3,
#     'eve': 47.48,
#     'morn': 50.18},
#    'feels_like': {'day': 47.53, 'night': 43.97, 'eve': 47.48, 'morn': 49.17},
#    'pressure': 1004,
#    'humidity': 98,
#    'dew_point': 46.24,
#    'wind_speed': 15.66,
#    'wind_deg': 145,
#    'wind_gust': 38.5,
#    'weather': [{'id': 502,
#      'main': 'Rain',
#      'description': 'heavy intensity rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 28.99,
#    'uvi': 1.44},
#   {'dt': 1649437200,
#    'sunrise': 1649414054,
#    'sunset': 1649461091,
#    'moonrise': 1649429820,
#    'moonset': 1649398980,
#    'moon_phase': 0.23,
#    'temp': {'day': 49.8,
#     'min': 39.07,
#     'max': 49.8,
#     'night': 40.01,
#     'eve': 43.02,
#     'morn': 39.07},
#    'feels_like': {'day': 45.93, 'night': 40.01, 'eve': 43.02, 'morn': 36.36},
#    'pressure': 1001,
#    'humidity': 65,
#    'dew_point': 37.89,
#    'wind_speed': 9.86,
#    'wind_deg': 258,
#    'wind_gust': 19.37,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 74,
#    'pop': 1,
#    'rain': 11.69,
#    'uvi': 4.25},
#   {'dt': 1649523600,
#    'sunrise': 1649500351,
#    'sunset': 1649547560,
#    'moonrise': 1649519580,
#    'moonset': 1649488260,
#    'moon_phase': 0.25,
#    'temp': {'day': 43.61,
#     'min': 35.62,
#     'max': 43.61,
#     'night': 35.62,
#     'eve': 39,
#     'morn': 39.51},
#    'feels_like': {'day': 40.23, 'night': 29.68, 'eve': 36.1, 'morn': 34.68},
#    'pressure': 1004,
#    'humidity': 83,
#    'dew_point': 37.63,
#    'wind_speed': 9.98,
#    'wind_deg': 288,
#    'wind_gust': 20.58,
#    'weather': [{'id': 616,
#      'main': 'Snow',
#      'description': 'rain and snow',
#      'icon': '13d'}],
#    'clouds': 97,
#    'pop': 0.95,
#    'rain': 3.37,
#    'snow': 0.11,
#    'uvi': 0.11},
#   {'dt': 1649610000,
#    'sunrise': 1649586649,
#    'sunset': 1649634030,
#    'moonrise': 1649609700,
#    'moonset': 1649577120,
#    'moon_phase': 0.29,
#    'temp': {'day': 39.67,
#     'min': 34.9,
#     'max': 41.47,
#     'night': 36.46,
#     'eve': 36.75,
#     'morn': 36.01},
#    'feels_like': {'day': 32.31, 'night': 31.3, 'eve': 30.94, 'morn': 29.1},
#    'pressure': 1012,
#    'humidity': 81,
#    'dew_point': 33.55,
#    'wind_speed': 12.33,
#    'wind_deg': 282,
#    'wind_gust': 20.54,
#    'weather': [{'id': 616,
#      'main': 'Snow',
#      'description': 'rain and snow',
#      'icon': '13d'}],
#    'clouds': 100,
#    'pop': 0.74,
#    'rain': 0.77,
#    'snow': 0.81,
#    'uvi': 1},
#   {'dt': 1649696400,
#    'sunrise': 1649672948,
#    'sunset': 1649720499,
#    'moonrise': 1649700060,
#    'moonset': 1649665500,
#    'moon_phase': 0.32,
#    'temp': {'day': 55.76,
#     'min': 32.43,
#     'max': 55.76,
#     'night': 55.51,
#     'eve': 52.18,
#     'morn': 37.81},
#    'feels_like': {'day': 53.67, 'night': 54.57, 'eve': 51.13, 'morn': 34.66},
#    'pressure': 1014,
#    'humidity': 56,
#    'dew_point': 39.58,
#    'wind_speed': 21.36,
#    'wind_deg': 199,
#    'wind_gust': 44.94,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 59,
#    'pop': 0.98,
#    'rain': 2.09,
#    'uvi': 1}]}

# %%
# then test them here to figue out how to extract from the dictionary
geodata = geocode('Syracuse, NY')
lat = geodata[0]['lat']
lon = geodata[0]['lon']
weather = getweather(lat, lon)
weather.keys()
# Out:
# dict_keys(['lat', 'lon', 'timezone', 'timezone_offset', 'current', 'minutely', 'hourly', 'daily'])

# %%
weather['daily']
# Out:
# [{'dt': 1649091600,
#   'sunrise': 1649068870,
#   'sunset': 1649115214,
#   'moonrise': 1649074920,
#   'moonset': 1649129100,
#   'moon_phase': 0.11,
#   'temp': {'day': 41.85,
#    'min': 33.01,
#    'max': 44.26,
#    'night': 36.59,
#    'eve': 42.87,
#    'morn': 33.01},
#   'feels_like': {'day': 37.18, 'night': 33.37, 'eve': 42.87, 'morn': 28.2},
#   'pressure': 1017,
#   'humidity': 73,
#   'dew_point': 33.84,
#   'wind_speed': 7.99,
#   'wind_deg': 309,
#   'wind_gust': 16.96,
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'clouds': 99,
#   'pop': 0.47,
#   'snow': 0.38,
#   'uvi': 4.39},
#  {'dt': 1649178000,
#   'sunrise': 1649155166,
#   'sunset': 1649201683,
#   'moonrise': 1649163120,
#   'moonset': 0,
#   'moon_phase': 0.14,
#   'temp': {'day': 55.44,
#    'min': 33.42,
#    'max': 58.71,
#    'night': 46.24,
#    'eve': 51.71,
#    'morn': 33.91},
#   'feels_like': {'day': 53.26, 'night': 42.53, 'eve': 49.82, 'morn': 29.08},
#   'pressure': 1014,
#   'humidity': 55,
#   'dew_point': 38.62,
#   'wind_speed': 7.25,
#   'wind_deg': 139,
#   'wind_gust': 20.67,
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': 30,
#   'pop': 0,
#   'uvi': 4.67},
#  {'dt': 1649264400,
#   'sunrise': 1649241461,
#   'sunset': 1649288152,
#   'moonrise': 1649251560,
#   'moonset': 1649219280,
#   'moon_phase': 0.17,
#   'temp': {'day': 53.87,
#    'min': 42.94,
#    'max': 55.04,
#    'night': 49.95,
#    'eve': 51.15,
#    'morn': 43.83},
#   'feels_like': {'day': 52.43, 'night': 44.83, 'eve': 49.96, 'morn': 39.72},
#   'pressure': 1009,
#   'humidity': 74,
#   'dew_point': 44.98,
#   'wind_speed': 16.06,
#   'wind_deg': 131,
#   'wind_gust': 36.78,
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'clouds': 80,
#   'pop': 0.88,
#   'rain': 2.28,
#   'uvi': 4.23},
#  {'dt': 1649350800,
#   'sunrise': 1649327758,
#   'sunset': 1649374622,
#   'moonrise': 1649340480,
#   'moonset': 1649309340,
#   'moon_phase': 0.2,
#   'temp': {'day': 47.53,
#    'min': 45.3,
#    'max': 50.74,
#    'night': 45.3,
#    'eve': 47.48,
#    'morn': 50.18},
#   'feels_like': {'day': 47.53, 'night': 43.97, 'eve': 47.48, 'morn': 49.17},
#   'pressure': 1004,
#   'humidity': 98,
#   'dew_point': 46.24,
#   'wind_speed': 15.66,
#   'wind_deg': 145,
#   'wind_gust': 38.5,
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10d'}],
#   'clouds': 100,
#   'pop': 1,
#   'rain': 28.99,
#   'uvi': 1.44},
#  {'dt': 1649437200,
#   'sunrise': 1649414054,
#   'sunset': 1649461091,
#   'moonrise': 1649429820,
#   'moonset': 1649398980,
#   'moon_phase': 0.23,
#   'temp': {'day': 49.8,
#    'min': 39.07,
#    'max': 49.8,
#    'night': 40.01,
#    'eve': 43.02,
#    'morn': 39.07},
#   'feels_like': {'day': 45.93, 'night': 40.01, 'eve': 43.02, 'morn': 36.36},
#   'pressure': 1001,
#   'humidity': 65,
#   'dew_point': 37.89,
#   'wind_speed': 9.86,
#   'wind_deg': 258,
#   'wind_gust': 19.37,
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'clouds': 74,
#   'pop': 1,
#   'rain': 11.69,
#   'uvi': 4.25},
#  {'dt': 1649523600,
#   'sunrise': 1649500351,
#   'sunset': 1649547560,
#   'moonrise': 1649519580,
#   'moonset': 1649488260,
#   'moon_phase': 0.25,
#   'temp': {'day': 43.61,
#    'min': 35.62,
#    'max': 43.61,
#    'night': 35.62,
#    'eve': 39,
#    'morn': 39.51},
#   'feels_like': {'day': 40.23, 'night': 29.68, 'eve': 36.1, 'morn': 34.68},
#   'pressure': 1004,
#   'humidity': 83,
#   'dew_point': 37.63,
#   'wind_speed': 9.98,
#   'wind_deg': 288,
#   'wind_gust': 20.58,
#   'weather': [{'id': 616,
#     'main': 'Snow',
#     'description': 'rain and snow',
#     'icon': '13d'}],
#   'clouds': 97,
#   'pop': 0.95,
#   'rain': 3.37,
#   'snow': 0.11,
#   'uvi': 0.11},
#  {'dt': 1649610000,
#   'sunrise': 1649586649,
#   'sunset': 1649634030,
#   'moonrise': 1649609700,
#   'moonset': 1649577120,
#   'moon_phase': 0.29,
#   'temp': {'day': 39.67,
#    'min': 34.9,
#    'max': 41.47,
#    'night': 36.46,
#    'eve': 36.75,
#    'morn': 36.01},
#   'feels_like': {'day': 32.31, 'night': 31.3, 'eve': 30.94, 'morn': 29.1},
#   'pressure': 1012,
#   'humidity': 81,
#   'dew_point': 33.55,
#   'wind_speed': 12.33,
#   'wind_deg': 282,
#   'wind_gust': 20.54,
#   'weather': [{'id': 616,
#     'main': 'Snow',
#     'description': 'rain and snow',
#     'icon': '13d'}],
#   'clouds': 100,
#   'pop': 0.74,
#   'rain': 0.77,
#   'snow': 0.81,
#   'uvi': 1},
#  {'dt': 1649696400,
#   'sunrise': 1649672948,
#   'sunset': 1649720499,
#   'moonrise': 1649700060,
#   'moonset': 1649665500,
#   'moon_phase': 0.32,
#   'temp': {'day': 55.76,
#    'min': 32.43,
#    'max': 55.76,
#    'night': 55.51,
#    'eve': 52.18,
#    'morn': 37.81},
#   'feels_like': {'day': 53.67, 'night': 54.57, 'eve': 51.13, 'morn': 34.66},
#   'pressure': 1014,
#   'humidity': 56,
#   'dew_point': 39.58,
#   'wind_speed': 21.36,
#   'wind_deg': 199,
#   'wind_gust': 44.94,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': 59,
#   'pop': 0.98,
#   'rain': 2.09,
#   'uvi': 1}]

# %%
import requests
# Now I can write the entire program...
location = input("Where are you? (eg. Syracuse, NY) : ")
geodata = geocode(location)
lat,lon = geodata[0]['lat'], geodata[0]['lon']
weather = getweather(lat,lon)
current = weather['current']
print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# Where are you? (eg. Syracuse, NY) : Syracuse NY
# https://nominatim.openstreetmap.org/search?q=Syracuse+NY&format=json
# Current conditions in Syracuse NY are broken clouds with a temperature of 43.38 degrees.

# %%
from IPython.display import display, HTML
from ipywidgets import interact_manual
import requests

display(HTML("<h1>Weather Forecaster</h1>"))
@interact_manual(location="")
def main(location):
    geodata = geocode(location)
    lat,lon = geodata[0]['lat'], geodata[0]['lon']
    weather = getweather(lat,lon)
    current = weather['current']
    print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# <h1>Weather Forecaster</h1>
# interactive(children=(Text(value='', description='location'), Button(description='Run Interact', style=ButtonS…

# %%
    weather = getweather(lat,lon)
    current = weather['current']
# Out:
# [{'place_id': 332268789,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 174916,
#   'boundingbox': ['42.984165', '43.086121', '-76.204629', '-76.074273'],
#   'lat': '43.0481221',
#   'lon': '-76.1474244',
#   'display_name': 'City of Syracuse, Onondaga County, New York, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6767762857760726,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'},
#  {'place_id': 67315254,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 6241108067,
#   'boundingbox': ['43.0718312', '43.0818312', '-76.1744003', '-76.1644003'],
#   'lat': '43.0768312',
#   'lon': '-76.1694003',
#   'display_name': 'Syracuse, 131, NBT Bank Parkway, City of Syracuse, Onondaga County, New York, 13208, United States',
#   'class': 'railway',
#   'type': 'station',
#   'importance': 0.4272524353626238,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//transport_train_station2.p.20.png'},
#  {'place_id': 36341573,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 2997656284,
#   'boundingbox': ['43.0770382', '43.0771382', '-76.1700021', '-76.1699021'],
#   'lat': '43.0770882',
#   'lon': '-76.1699521',
#   'display_name': 'Syracuse, Walsh Circle, City of Syracuse, Onondaga County, New York, 13290, United States',
#   'class': 'railway',
#   'type': 'stop',
#   'importance': 0.11100000000000002}]
